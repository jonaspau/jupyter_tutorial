# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a widely used python library for data analysis.
#
# This tutorial is an introduction to how to create, import and work with data.

# %%
# Mostly used way to import pandas to python
import pandas as pd

# %%
# setting up pandas for better displaying:
pd.set_option('display.max_rows', 5)

# %% [markdown]
# ## Core data objects in pandas
#
# The main data objects in pandas are Dataframes and Series.

# %% [markdown]
# ### DataFrames
# DataFrames are tables consisting of an array of entries. Each entry corresponds to a row aand column:

# %%
pd.DataFrame({"Yes": [10, 20], "No": [30, 40]})
# Out:
#    Yes  No
# 0   10  30
# 1   20  40

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series
# Series are sequences of data. Compared to a DataFrame, a series would be an entity only containing one column.

# %%
pd.Series([10, 20, 30, 40, 50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series([10, 20, 30, 40, 50], index = ["Sales 2015", "Sales 2016", "Sales 2017", "Sales 2018", "Sales 2019"], name = "Sales Product A")
# Out:
# Sales 2015    10
# Sales 2016    20
# Sales 2017    30
# Sales 2018    40
# Sales 2019    50
# Name: Sales Product A, dtype: int64

# %% [markdown]
# ## Importing data

# %% [raw]
# Rather than entering data, we coomonly use pandas' read function:

# %%
reviews = pd.read_csv("./files/winemag-data-130k-v2.csv")

# %% [markdown]
# To verify that we imported data we can run:

# %%
reviews.shape
# Out:
# (129971, 14)

# %% [raw]
# we can see a sample of our data by running:

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# There seems to be an indexing column in the data set already, so now we have two.
#
# We can import the data with an indexing column by running the following:

# %%
reviews = pd.read_csv("./files/winemag-data-130k-v2.csv", index_col=0)
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ## Indexing, Selecting and Assigning

# %% [markdown]
# In pandas we can access specific data in a DataFrame in the same way as in Python in general

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.description
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
reviews["country"]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
# To access a set of columns this way, we need to provide them in square brackets
reviews[["country", "description"]]
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 2 columns]

# %%
# We can access a column, and only request a set of rows:
reviews["country"][0:3]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %% [markdown]
# ### Indexing, loc and iloc

# %%
# See the first eenrty obf a DataFrame
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.iloc[2:5, :3]
# Out:
#   country                                        description  \
# 2      US  Tart and snappy, the flavors of lime flesh and...
# 3      US  Pineapple rind, lemon pith and orange blossom ...
# 4      US  Much like the regular bottling from 2012, this...
#
#                           designation
# 2                                 NaN
# 3                Reserve Late Harvest
# 4  Vintner's Reserve Wild Child Block

# %%
reviews.iloc[:5, :3]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation
# 0                        Vulkà Bianco
# 1                            Avidagos
# 2                                 NaN
# 3                Reserve Late Harvest
# 4  Vintner's Reserve Wild Child Block

# %%
reviews.iloc[-5:, :3]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese
# 129967                                     NaN
# 129968                                   Kritt
# 129969                                     NaN
# 129970           Lieu-dit Harth Cuvée Caroline

# %%
reviews.loc[:, 'country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.loc[:, ["country", "taster_name", "points"]]
# Out:
#          country    taster_name  points
# 0          Italy  Kerin O’Keefe      87
# 1       Portugal     Roger Voss      87
# ...          ...            ...     ...
# 129969    France     Roger Voss      90
# 129970    France     Roger Voss      90
#
# [129971 rows x 3 columns]

# %%
sample = [1, 2, 3, 5, 8]
sample_reviews = reviews.loc[sample]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %%
sample = [0, 1, 10, 100]
reviews.loc[sample, ["country", "province", "region_1"]]
# Out:
#       country           province      region_1
# 0       Italy  Sicily & Sardinia          Etna
# 1    Portugal              Douro           NaN
# 10         US         California   Napa Valley
# 100        US           New York  Finger Lakes

# %%
reviews.loc[0:99, ["country", "variety"]]
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %% [markdown]
# **Choosing between loc and iloc**
#
# The two methods use slightly different indexing schemes.
#
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.
#
# Why the change? Remember that loc can index any stdlib type: strings, for example. If we have a DataFrame with index values Apples, ..., Potatoes, ..., and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index df.loc['Apples':'Potatoes'] than it is to index something like df.loc['Apples', 'Potatoet'] (t coming after s in the alphabet).
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999].
#
# Otherwise, the semantics of using loc are the same as those for iloc.

# %% [markdown]
# ### Manipulating the index

# %% [markdown]
# We can change the index with the set_index() method if we realise that we can use another index in the data:

# %%
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %% [markdown]
# ### Conditional selection

# %%
reviews.country == "Italy"
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[reviews.country == "Italy"]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == "Italy") & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
top_oceania_wines = reviews.loc[(reviews.country.isin(["Australia", "New Zealand"])) & (reviews.points >= 95)]
top_oceania_wines
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# ...             ...                                                ...
# 122507  New Zealand  This blend of Cabernet Sauvignon (62.5%), Merl...
# 122939    Australia  Full-bodied and plush yet vibrant and imbued w...
#
#                                   designation  points  price         province  \
# 345                                      Rare     100  350.0         Victoria
# 346                                      Rare      98  350.0         Victoria
# ...                                       ...     ...    ...              ...
# 122507  SQM Gimblett Gravels Cabernets/Merlot      95   79.0      Hawke's Bay
# 122939                             The Factor      98  125.0  South Australia
#
# ...

# %%
reviews.loc[(reviews.country == "Italy") | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[(reviews.country.isin(["Italy", "France"])) & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 119     France  Medium-gold in color. Complex and inviting nos...
# 120      Italy  Slightly backward, particularly given the vint...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                        designation  points  price  province  \
# 119     Schoenenbourg Grand Cru Vendanges Tardives      92   80.0    Alsace
# 120                            Bricco Rocche Prapó      92   70.0  Piedmont
# ...                                            ...     ...    ...       ...
# 129969                                         NaN      90   32.0    Alsace
# 129970               Lieu-dit Harth Cuvée Caroline      90   21.0    Alsace
#
#        region_1 region_2 taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %% [markdown]
# ### Assigning data

# %%
reviews["critic"] = "everyone"
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews["index_back"] = range(len(reviews), 0, -1)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# ## Renaming and combining

# %% [markdown]
# To make more sense of the column names we can rename them:

# %%
reviews.rename(columns={"region_1": "region", "region_2": "locale"})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region locale    taster_name taster_twitter_handle  \
# 0         Etna    NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %% [markdown]
# We can also rename by index, essentially rewriting data in one or more rows:

# %%
reviews.rename(index={0:"first", 1:"second"} )
# Out:
#          country                                        description  \
# first      Italy  Aromas include tropical fruit, broom, brimston...
# second  Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# first                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# second                       Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# We can also rename the columns and rows:

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# We can merge two datasetes with teh concat() function:

# %%
top_french_wines = reviews.loc[(reviews.country == "France") & (reviews.points >= 100)]
top_italian_wines = reviews.loc[(reviews.country == "Italy") & (reviews.points >= 100)]

pd.concat([top_french_wines, top_italian_wines])
# Out:
#        country                                        description designation  \
# 36528   France  This is a fabulous wine from the greatest Cham...        Brut
# 58352   France  This is a magnificently solid wine, initially ...         NaN
# ...        ...                                                ...         ...
# 45781    Italy  This gorgeous, fragrant wine opens with classi...     Riserva
# 111754   Italy  It takes only a few moments before you appreci...  Cerretalto
#
#         points  price   province                region_1 region_2  \
# 36528      100  259.0  Champagne               Champagne      NaN
# 58352      100  150.0   Bordeaux            Saint-Julien      NaN
# ...        ...    ...        ...                     ...      ...
# 45781      100  550.0    Tuscany  Brunello di Montalcino      NaN
# 111754     100  270.0    Tuscany  Brunello di Montalcino      NaN
#
#           taster_name taster_twitter_handle  \
# 36528      Roger Voss            @vossroger
# ...

# %% [markdown]
# we can join two dataframes next to each other by using join:

# %%
ca_vids = pd.read_csv("./files/CAvideos.csv")
gb_vids = pd.read_csv("./files/GBvideos.csv")

vids = ca_vids.join(gb_vids, lsuffix="_CA", rsuffix="_GB")

vids
# Out:
#        video_id_CA trending_date_CA  \
# 0      n1WpP7iowLc         17.14.11
# 1      0dBIkQ4Mz1M         17.14.11
# ...            ...              ...
# 40879  lbMKLzQ4cNQ         18.14.06
# 40880  POTgw38-m58         18.14.06
#
#                                          title_CA channel_title_CA  \
# 0      Eminem - Walk On Water (Audio) ft. Beyoncé       EminemVEVO
# 1                   PLUSH - Bad Unboxing Fan Mail        iDubbbzTV
# ...                                           ...              ...
# 40879            Trump Advisor Grovels To Trudeau  The Young Turks
# 40880            【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班         我愛小明星大跟班
#
#        category_id_CA           publish_time_CA  \
# 0                  10  2017-11-10T17:00:03.000Z
# 1                  23  2017-11-13T17:00:00.000Z
# ...               ...                       ...
# 40879              25  2018-06-13T04:00:05.000Z
# 40880              24  2018-06-13T16:00:03.000Z
#
# ...

# %% [markdown]
# ## Summary functions and maps

# %% [markdown]
# Using "summary functions" we can restructure the data and get an overview of the dataa

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %% [markdown]
# The describe funtion gives a type-aware overview of the data in a column.

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.country.describe()
# Out:
# count     129908
# unique        43
# top           US
# freq       54504
# Name: country, dtype: object

# %% [markdown]
# We can also usee other functions to get specific descriptive data:

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %% [markdown]
# Using mapping we can remap a value, for example by remapping the mean to 0:

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# Theres also a function for doing the same without a lambda function:
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# We can now see the deviation from the mean, rather than the mean.

# %% [markdown]
# While map() creates a new series of the data, we can also remap in the existing df with apply()
# to store the new values we need to set a new df name, or overwrite with df = df.apply()

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

# This code chrashes when run in VS Code:
# reviews_remeaned = reviews.apply(remean_points, axis='columns')

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# ## Grouping and sorting

# %% [markdown]
# ### Grouping

# %% [markdown]
# Grouping of our data can make our data easier to understand and summrize.
#
# the `.groupby()` function can give a good overview:

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %% [markdown]
# The groupings are essentially smaller DataFrames, we can access the contents and for example show the first wine in the lis produced by each winery:

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %% [markdown]
# Or we can pick the best wine of each province grouped by country:

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %% [markdown]
# The `.agg()` function gives us the possibility to aggregate the data in our groupings.
#
# For example we can take the wine price in each province and count the prices, as well as show the min and max price:

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
# /tmp/ipykernel_76601/4122224884.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby(['country']).price.agg([len, min, max])
# /tmp/ipykernel_76601/4122224884.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby(['country']).price.agg([len, min, max])
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %% [markdown]
# ### Multi-indexes

# %% [markdown]
# The above example is an multi-index. Multi-indexes are layered with mere than one index.

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# We can flatten the multi-index, essentially creating a new df that is grouped according to the multi-index, but containing data in all the indexing columns:

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# ### Sorting

# %% [markdown]
# When using `groupby()` the order of the rows is depending on the values in the index, not the data.
#
# When we want the data in a certain order we may also want to sort it, for this we can use `.sort-values()`

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by="len")
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# ..      ...                    ...    ...
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %% [markdown]
# To turn the sorting we can disable ascending:

# %%
countries_reviewed.sort_values(by="len", ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %% [markdown]
# And we can re-sort by index:

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# We can also sort by more than one column:

# %%
countries_reviewed.sort_values(by=["country", "len"])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# ..         ...               ...   ...
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %% [markdown]
# ## Data types and missing values

# %% [markdown]
# ### Data types in Pandas

# %% [markdown]
# The data type for a single column in a df or series is referred to as a dtype.
#
# We can find the dtype by using the `dtype`property on a column, or `dtypes`on the df itself:

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# critic         object
# index_back      int64
# Length: 15, dtype: object

# %% [markdown]
# Using the `astype()`method we can convert from one type to another:

# %%
reviews.points.astype("int64")
# Out:
# 0         87
# 1         87
#           ..
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
reviews.points.astype("float64")
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# ### Missing data

# %% [markdown]
# If we want to selct all the data that has null values we can use the `isnull()` method. We can also select the non-null vaules by using `notnull()`

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %%
reviews.price.isnull().sum()
# Out:
# 8996

# %% [markdown]
# if we want to replace missing values we can use `fillna()` with different methods:
#
# - Replacing
# - Backfilling
#
# We can also use the `replace()` method to replace existing content

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews_region_1 = reviews.region_1.fillna("Unknown")
reviews_per_region = reviews_region_1.value_counts().sort_values(ascending=False)
reviews_per_region
# Out:
# region_1
# Unknown        21247
# Napa Valley     4480
#                ...
# Geelong            1
# Paestum            1
# Name: count, Length: 1230, dtype: int64
